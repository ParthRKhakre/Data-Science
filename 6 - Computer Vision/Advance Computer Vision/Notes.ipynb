# %%
# import cv2 as cv

# %%
# cap = cv.VideoCapture(0)
# cv.VideoCapture returns a video object.
# 0 -> default and 1,2 are other cameras(if available) and "video.mp4" for video files

# %%
# ret, frame = cap.read()
# ret -> True/False (tells Whether frame was captured successfully)
# frame -> the actual image(frame)
