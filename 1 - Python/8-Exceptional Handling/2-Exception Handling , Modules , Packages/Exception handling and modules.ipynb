# %% [markdown]
# # There are 2 stages where error may happen in program
# * During compilation - Syntax error
# * During Execution - Exception
#
# # Syntax Error
# * Something in the program is not written accordingly to the program grammar
# * Error is raised by the interpreter/Compiler
# * You can solve it by rectifying the program

# %%
# Example of syntax error 
print 'Hello'
# Out:
#   Cell In[1], line 2
#     print 'Hello'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# # Other examples of syntax error
# * Leaving symbols like colon,brackets
# * Misspelling a keyword
# * Incorrect Indectation
# * empty if else loog class function

# %%
a = 9
if a == 0
    print("hello")
# Out:
#   Cell In[2], line 2
#     if a == 0
#              ^
# SyntaxError: expected ':'

# %%
a = 9 
iff a ==9:
    print("Hmm")
# Out:
#   Cell In[3], line 2
#     iff a ==9:
#         ^
# SyntaxError: invalid syntax

# %%
a = 9 
if a ==9:
print("Hmm")
# Out:
#   Cell In[5], line 3
#     print("Hmm")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
L = [1,2,3,4]
print(L[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 # IndexError
#       2 # The IndexError is thrown when trying to access an item at an invalid index.
#       3 L = [1,2,3,4]
# ----> 4 print(L[10])
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
a = math.sqrt(9)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # ModuleNotFoundError
#       2 # The ModuleNotFoundError is thrown when a module could not be found.
# ----> 3 import mathi
#       4 a = math.sqrt(9)
#
# ModuleNotFoundError: No module named 'mathi'

# %%
# KeyError(often occur in dictionary)
# The Keyword is thrown when a key is not found 

dic = {"name":"nitish"}
dic["age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 5
#       1 # KeyError(often occur in dictionary)
#       2 # The Keyword is thrown when a key is not found
#       4 dic = {"name":"nitish"}
# ----> 5 dic["age"]
#
# KeyError: 'age'

# %%
# TypeError
# is thrown when an operation or function is applied to an object of an inappropriate type
1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # TypeError
#       2 # is thrown when an operation or function is applied to an object of an inappropriate type
# ----> 3 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ValueError 
# is thrown when a function's argument is of inappropriate type. 
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 # ValueError
#       2 # is thrown when a function's argument is of inappropriate type.
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# NameError
# is thrown when an object could not found
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # NameError
#       2 # is thrown when an object could not found
# ----> 3 print(k)
#
# NameError: name 'k' is not defined

# %%
# attribute error
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 # attribute error
#       2 L = [1,2,3]
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'
